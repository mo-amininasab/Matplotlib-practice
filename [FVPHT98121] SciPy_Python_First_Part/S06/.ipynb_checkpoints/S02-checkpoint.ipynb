# %% [markdown]
# # Equation Solving

# %% [markdown]
# ## Importing Modules

# %%
#!pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.5.3-cp38-cp38-win_amd64.whl (31.4 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\studio\anaconda3\lib\site-packages (from scipy) (1.19.2)
# Installing collected packages: scipy
# Successfully installed scipy-1.5.3

# %%
from scipy import linalg as la

# %%
from scipy import optimize

# %%
import sympy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear Equation Systems

# %% [markdown]
# > ### Square Systems

# %%
A = sympy.Matrix([[2, 3], [5, 4]])
b = sympy.Matrix([4, 3])

# %%
A.rank()
# Out:
# 2

# %%
A.condition_number()
# Out:
# sqrt(2*sqrt(170) + 27)/sqrt(27 - 2*sqrt(170))

# %%
sympy.N(_)
# Out:
# 7.58240137440151

# %%
A.norm()
# Out:
# 3*sqrt(6)

# %%
A = np.array([[2, 3], [5, 4]])
b = np.array([4, 3])

# %%
np.linalg.matrix_rank(A)
# Out:
# 2

# %%
np.linalg.cond(A)
# Out:
# 7.582401374401516

# %%
np.linalg.norm(A)
# Out:
# 7.3484692283495345

# %%
A = sympy.Matrix([[2, 3], [5, 4]])
b = sympy.Matrix([4, 3])

# %%
L, U, _ = A.LUdecomposition()

# %%
L
# Out:
# Matrix([
# [  1, 0],
# [5/2, 1]])

# %%
U
# Out:
# Matrix([
# [2,    3],
# [0, -7/2]])

# %%
L*U
# Out:
# Matrix([
# [2, 3],
# [5, 4]])

# %%
x = A.LUsolve(b)

# %%
x
# Out:
# Matrix([
# [-1],
# [ 2]])

# %%
x = A.solve(b)

# %%
x
# Out:
# Matrix([
# [-1],
# [ 2]])

# %%
A = PLU

# %%
A = np.array([[2, 3], [5, 4]])
b = np.array([4, 3])

# %%
P, L, U = la.lu(A)

# %%
L
# Out:
# array([[1. , 0. ],
#        [0.4, 1. ]])

# %%
U
# Out:
# array([[5. , 4. ],
#        [0. , 1.4]])

# %%
P.dot(L.dot(U))
# Out:
# array([[2., 3.],
#        [5., 4.]])

# %%
la.solve(A, b)
# Out:
# array([-1.,  2.])

# %%
p = sympy.symbols("p", positive=True)

# %%
A = sympy.Matrix([[1, sympy.sqrt(p)], [1, 1/sympy.sqrt(p)]])

# %%
b = sympy.Matrix([1, 2])

# %%
x = A.solve(b)

# %%
x
# Out:
# Matrix([
# [       (2*p - 1)/(p - 1)],
# [1/(-sqrt(p) + 1/sqrt(p))]])

# %%
#symbolic problem
p = sympy.symbols("p", positive=True)
A = sympy.Matrix([[1, sympy.sqrt(p)], [1, 1/sympy.sqrt(p)]])
b = sympy.Matrix([1, 2])

#solve_symbolically
x_sym_sol = A.solve(b)
Acond = A.condition_number().simplify()

#Numerical
AA = lambda p: np.array([[1, np.sqrt(p)], [1, 1/np.sqrt(p)]])
bb = np.array([1, 2])
x_num_sol = lambda p: np.linalg.solve(AA(p), bb)

#graph the result
fig, axes = plt.subplots(1, 2, figsize=(11, 4))

p_vec = np.linspace(0.9, 1.1, 300)
for n in range(2):
    x_sym = np.array([x_sym_sol[n].subs(p, pp).evalf() for pp in p_vec])
    x_num = np.array([x_num_sol(pp)[n] for pp in p_vec])
    axes[0].plot(p_vec, (x_num - x_sym)/x_sym, 'k')
    
axes[0].set_title("Error in solution\n(numerical - symbolic)/symbolic")
axes[0].set_xlabel(r"$p$", fontsize=18)

axes[1].plot(p_vec, [Acond.subs(p, pp).evalf() for pp in p_vec])
axes[1].set_title("Condition number")
axes[1].set_xlabel(r"$p$", fontsize=18)
# Out:
# Text(0.5, 0, '$p$')

# %% [markdown]
# > ### Rectangular Systems

# %%
x_vars = sympy.symbols("x_1, x_2, x_3")

# %%
A = sympy.Matrix([[1, 2, 3], [4, 5, 6]])

# %%
x = sympy.Matrix(x_vars)
b = sympy.Matrix([7, 8])

# %%
sympy.solve(A*x - b, x_vars)
# Out:
# {x_2: 20/3 - 2*x_3, x_1: x_3 - 19/3}

# %%
#overdetermined

# %%
x = np.linspace(-1, 1, 100)
a, b, c = 1, 2, 3
y_exact = a + b * x + c * x**2

# %%
#noisy data
m = 100
X = 1 - 2 * np.random.rand(m)
Y = a + b * X + c * X**2 + np.random.randn(m)

# %%
#fit
A = np.vstack([X**0, X**1, X**2])
sol, r, rank, sv = la.lstsq(A.T, Y)

# %%
y_fit = sol[0] + sol[1] * x + sol[2] * x**2

# %%
fig, ax = plt.subplots(figsize=(11, 4))

ax.plot(X, Y, 'go', alpha=0.5, label='Simulated data')
ax.plot(x, y_exact, 'k', lw=2, label='True value $y = 1 + 2x + 3x^2$')
ax.plot(x, y_fit, 'b', lw=2, label='Least Square fit')
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$y$", fontsize=18)
ax.legend(loc=2)

# %%
#1st order
A = np.vstack([X**n for n in range(2)])
sol, r, rank, sv = la.lstsq(A.T, Y)
y_fit1 = sum([s * x**n for n, s in enumerate(sol)])

#15th order
A = np.vstack([X**n for n in range(16)])
sol, r, rank, sv = la.lstsq(A.T, Y)
y_fit15 = sum([s * x**n for n, s in enumerate(sol)])

fig, ax = plt.subplots(figsize=(11, 4))
ax.plot(X, Y, 'go', alpha=0.5, label='Simulated data')
ax.plot(x, y_exact, 'k', lw=2, label='True value $y = 1 + 2x + 3x^2$')
ax.plot(x, y_fit1, 'b', lw=2, label='Least square fit [1st oredr]')
ax.plot(x, y_fit15, 'm', lw=2, label='Least square fit [15th oredr]')
ax.set_xlabel(r"$x$", fontsize=18)
ax.set_ylabel(r"$y$", fontsize=18)
ax.legend(loc=2)

# %% [markdown]
# ## Eigenvalue Problems

# %%
#sympy -> eigenvals, eigenvects

# %%
eps, delta = sympy.symbols("epsilon, Delta")

# %%
H = sympy.Matrix([[eps, delta], [delta, -eps]])

# %%
H
# Out:
# Matrix([
# [epsilon,    Delta],
# [  Delta, -epsilon]])

# %%
H.eigenvals()
# Out:
# {-sqrt(Delta**2 + epsilon**2): 1, sqrt(Delta**2 + epsilon**2): 1}

# %%
H.eigenvects()
# Out:
# [(-sqrt(Delta**2 + epsilon**2),
#   1,
#   [Matrix([
#    [-Delta/(epsilon + sqrt(Delta**2 + epsilon**2))],
#    [                                             1]])]),
#  (sqrt(Delta**2 + epsilon**2),
#   1,
#   [Matrix([
#    [-Delta/(epsilon - sqrt(Delta**2 + epsilon**2))],
#    [                                             1]])])]

# %%
(eval1, _, evec1), (eval2, _, evec2) = H.eigenvects()

# %%
sympy.simplify(evec1[0].T * evec2[0])
# Out:
# Matrix([[0]])

# %%
#scipy -> la.eigvals, la.eig

# %%
A = np.array([[1, 3, 5], [3, 5, 3], [5, 3, 9]])

# %%
evals, evecs = la.eig(A)

# %%
evals
# Out:
# array([13.35310908+0.j, -1.75902942+0.j,  3.40592034+0.j])

# %%
evecs
# Out:
# array([[ 0.42663918,  0.90353276, -0.04009445],
#        [ 0.43751227, -0.24498225, -0.8651975 ],
#        [ 0.79155671, -0.35158534,  0.49982569]])

# %%
la.eigvalsh(A)
# Out:
# array([-1.75902942,  3.40592034, 13.35310908])

# %% [markdown]
# ## Nonlinear Equations

# %% [markdown]
# > ### Univariate Equations

# %%
x, a, b, c = sympy.symbols("x, a, b, c")

# %%
sympy.solve(a + b*x + c*x**2, x)
# Out:
# [(-b + sqrt(-4*a*c + b**2))/(2*c), -(b + sqrt(-4*a*c + b**2))/(2*c)]

# %%
sympy.solve(a * sympy.cos(x) - b * sympy.sin(x), x)
# Out:
# [-2*atan((b - sqrt(a**2 + b**2))/a), -2*atan((b + sqrt(a**2 + b**2))/a)]

# %%
sympy.solve(sympy.sin(x)-x, x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-24-d3ec18de60c6> in <module>
# ----> 1 sympy.solve(sympy.sin(x)-x, x)
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1092     ###########################################################################
#    1093     if bare_f:
# -> 1094         solution = _solve(f[0], *symbols, **flags)
#    1095     else:
#    1096         solution = _solve_system(f, symbols, **flags)
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1692
#    1693     if result is False:
# -> 1694         raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1695
#    1696     if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [x, sin(x)]
# No algorithms are implemented to solve equation -x + sin(x)

# %%
x = np.linspace(-2, 2, 1000)
f1 = x**2 - x - 1
f2 = x**3 - 3 * np.sin(x)
f3 = np.exp(x) - 2
f4 = 1 - x**2 + np.sin(50 / (1 + x**2))

fig, axes = plt.subplots(1, 4, figsize=(11, 3), sharey=True)

for n, f in enumerate([f1, f2, f3, f4]):
    axes[n].plot(x, f, lw=1.5)
    axes[n].axhline(0, ls=':', color='k')
    axes[n].set_ylim(-5, 5)
    axes[n].set_xticks([-2, -1, 0, 1, 2])
    axes[n].set_xlabel(r'$x$', fontsize=18)
    
axes[0].set_ylabel(r'$f(x)$', fontsize=18)

titles = [r'$f(x)=x^2-x-1$', r'$f(x)=x^3-3\sin(x)$',
         r'$f(x)=\exp(x)-2$', r'$f(x)=\sin\left(50/(1+x^2)\right)+1-x^2$']

for n, title in enumerate(titles):
    axes[n].set_title(title)

# %%
#bisection
f = lambda x: np.exp(x) - 2
tol = 0.1
a, b = -2, 2
x = np.linspace(-2.1, 2.1, 1000)

fig, ax = plt.subplots(1, 1, figsize=(11, 4))

ax.plot(x, f(x), lw=1.5)
ax.axhline(0, ls=':', color='k')
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x)$', fontsize=18)

fa, fb = f(a), f(b)

ax.plot(a, fa, 'ko')
ax.plot(b, fb, 'ko')
ax.text(a, fa+0.5, r"$a$", ha='center', fontsize=18)
ax.text(b, fb+0.5, r"$b$", ha='center', fontsize=18)

n = 1
while b - a > tol:
    m = a + (b - a)/2
    fm = f(m)
    
    ax.plot(m, fm, 'ko')
    ax.text(m, fm - 0.5, r"$m_%d$" % n, ha='center')
    n += 1
    
    if np.sign(fa) == np.sign(fm):
        a, fa = m, fm
    else:
        b, fb = m, fm
        
ax.plot(m, fm, 'r*', markersize=10)
ax.annotate("Root approximately at %0.3f" % m, fontsize=14, family="serif",
           xy = (a, fm), xycoords='data', xytext=(-1, 3), 
            arrowprops=dict(arrowstyle="->", 
                            connectionstyle="arc3, rad=-.5"))
ax.set_title("Bisection Method")
# Out:
# Text(0.5, 1.0, 'Bisection Method')

# %%
#Newton
tol = 0.01
xk = 2

s_x = sympy.symbols("x")
s_f = sympy.exp(s_x) - 2

f = lambda x: sympy.lambdify(s_x, s_f)(x)
fp = lambda x: sympy.lambdify(s_x, sympy.diff(s_f, s_x))(x)

x = np.linspace(-1, 2.1, 1000)

fig, ax = plt.subplots(1, 1, figsize=(11, 4))
ax.plot(x, f(x))
ax.axhline(0, ls=':', color='k')

n = 0
while f(xk) > tol:
    xk_new = xk - f(xk) / fp(xk)
    
    ax.plot([xk, xk], [0, f(xk)], color='k', ls=':')
    ax.plot(xk, f(xk), 'ko')
    ax.text(xk, -.5, r'$x_%d$' % n, ha='center')
    ax.plot([xk, xk_new], [f(xk), 0], 'k-')
    
    xk = xk_new
    n += 1

ax.plot(xk, f(xk), 'r*', markersize=15)
ax.annotate("Root approximately at %0.3f" % xk,fontsize=14, family="serif",
           xy = (xk,f(xk)), xycoords='data', xytext=(-1, 3), 
            arrowprops=dict(arrowstyle="->", 
                            connectionstyle="arc3, rad=-.5"))
ax.set_title("Newton's Method")
ax.set_xticks([-1, 0, 1, 2])
# Out:
# [<matplotlib.axis.XTick at 0x183751c5d30>,
#  <matplotlib.axis.XTick at 0x183751c55e0>,
#  <matplotlib.axis.XTick at 0x18375257dc0>,
#  <matplotlib.axis.XTick at 0x18375198bb0>]

# %%
optimize.bisect(lambda x: np.exp(x) - 2, -2, 2)
# Out:
# 0.6931471805601177

# %%
f = lambda x: np.exp(x) - 2

# %%
x_root_guess = 2

# %%
fprime = lambda x: np.exp(x)

# %%
optimize.newton(f, x_root_guess)
# Out:
# 0.6931471805599455

# %%
optimize.newton(f, x_root_guess, fprime=fprime)
# Out:
# 0.6931471805599453

# %%
optimize.brentq(lambda x: np.exp(x) - 2, -2, 2)
# Out:
# 0.6931471805599453

# %%
optimize.brenth(lambda x: np.exp(x) - 2, -2, 2)
# Out:
# 0.6931471805599381

# %% [markdown]
# > ### Systems of Nonlinear Equations

# %%
def f(x):
    return [x[1] - x[0]**3 - 2 * x[0]**2 + 1, x[1] + x[0]**2 - 1]

# %%
optimize.fsolve(f, [1, 1])
# Out:
# array([0.73205081, 0.46410162])

# %%
x, y = sympy.symbols("x, y")

# %%
f_mat = sympy.Matrix([y - x**3 - 2*x**2 + 1, y + x**2 - 1])

# %%
f_mat.jacobian(sympy.Matrix([x, y]))
# Out:
# Matrix([
# [-3*x**2 - 4*x, 1],
# [          2*x, 1]])

# %%
def f_jacobian(x):
    return [[-3*x[0]**2-4*x[0], 1], [2*x[0], 1]]

# %%
optimize.fsolve(f, [1, 1], fprime=f_jacobian)
# Out:
# array([0.73205081, 0.46410162])

# %%
optimize.broyden1(f, [1, 1])
# Out:
# array([0.73205046, 0.46410254])

# %%
optimize.broyden2(f, [1, 1])
# Out:
# array([0.73205083, 0.4641017 ])

# %%
def f(x):
    return [x[1] - x[0]**3 - 2 * x[0]**2 + 1, 
            x[1] + x[0]**2 - 1]

x = np.linspace(-3, 2, 5000)
y1 = x**3 + 2 * x**2 - 1
y2 = -x**2 + 1

fig, ax = plt.subplots(figsize=(9, 4))

ax.plot(x, y1, 'b', lw=1.5, label=r'$y = x^3 + 2x^2 - 1$')
ax.plot(x, y2, 'g', lw=1.5, label=r'$y = -x^2 + 1$')

x_guesses = [[-2, 2], [1, -1], [-2, -5]]
for x_guess in x_guesses:
    sol = optimize.fsolve(f, x_guess)
    ax.plot(sol[0], sol[1], 'r*', markersize=16)
    ax.plot(x_guess[0], x_guess[1], 'ko')
    ax.annotate("", xy=(sol[0], sol[1]), 
                xytext=(x_guess[0], x_guess[1]),
               arrowprops=dict(arrowstyle="->", linewidth=2.5))

ax.legend(loc=0)
ax.set_xlabel(r'$x$', fontsize=16)
# Out:
# Text(0.5, 0, '$x$')

# %%
fig, ax = plt.subplots(figsize=(9, 4))

ax.plot(x, y1, 'k', lw=1.5)
ax.plot(x, y2, 'k', lw=1.5)

sol1 = optimize.fsolve(f, [-2, 2])
sol2 = optimize.fsolve(f, [1, -1])
sol3 = optimize.fsolve(f, [-2, -5])
sols = [sol1, sol2, sol3]
colors=['r', 'b', 'g']

for idx, s in enumerate(sols):
    ax.plot(s[0], s[1], colors[idx]+'*', markersize=16)
    
for m in np.linspace(-4, 3, 80):
    for n in np.linspace(-15, 15, 40):
        x_guess = [m, n]
        sol = optimize.fsolve(f, x_guess)
        idx = (abs(sols - sol)**2).sum(axis=1).argmin()
        ax.plot(x_guess[0], x_guess[1], colors[idx]+'.')

ax.set_xlabel(r'$x$', fontsize=16)
# Out:
# C:\Users\studio\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Text(0.5, 0, '$x$')
